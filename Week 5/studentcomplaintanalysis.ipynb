# %% [markdown]
# # Getting Stated with Clustering
# ## Student Complaint Dataset

# %% [markdown]
# The student complaint dataset, obtained from kaggle (https://www.kaggle.com/datasets/omarsobhy14/university-students-complaints-and-reports?resource=download) consist of reports and complaints of student within a university. The complaints ranges from workload, to welfare, security and so on. The dataset contains 1005 records and 7 columns inclusing Genre, Report, Age, Gpa, Year, Count and Gender. From this data, insight can be obtained to address the pressing needs of students.

# %% [markdown]
# ##### Installing Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px

# %% [markdown]
# ##### Importing Data

# %%
df = pd.read_csv("university_student_complaint.csv")
df
# Out:
#                                Genre  \
# 0     Academic Support and Resources
# 1     Academic Support and Resources
# 2     Academic Support and Resources
# 3     Academic Support and Resources
# 4     Academic Support and Resources
# ...                              ...
# 1000               Food and Cantines
# 1001               Food and Cantines
# 1002               Food and Cantines
# 1003               Food and Cantines
# 1004               Food and Cantines
#
#                                                 Reports  Age   Gpa  Year  \
# 0     The limited access to research databases and m...   27  2.18     2
# 1     I'm having trouble finding the course material...   23  3.11     2
# 2     It's frustrating to have limited access to res...   20  3.68     2
# 3     I'm really struggling in one of my classes but...   20  1.30     2
# 4      I am really struggling with understanding the...   26  2.50     2
# ...

# %% [markdown]
# # Getting Stated with Clustering
# ## Student Complaint Dataset

# %% [markdown]
# The student complaint dataset, obtained from kaggle (https://www.kaggle.com/datasets/omarsobhy14/university-students-complaints-and-reports?resource=download) consist of reports and complaints of student within a university. The complaints ranges from workload, to welfare, security and so on. The dataset contains 1005 records and 7 columns inclusing Genre, Report, Age, Gpa, Year, Count and Gender. From this data, insight can be obtained to address the pressing needs of students.

# %% [markdown]
# ##### Installing Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px

# %% [markdown]
# ##### Importing Data

# %%
df = pd.read_csv("university_student_complaint.csv")
df
# Out:
#                                Genre  \
# 0     Academic Support and Resources
# 1     Academic Support and Resources
# 2     Academic Support and Resources
# 3     Academic Support and Resources
# 4     Academic Support and Resources
# ...                              ...
# 1000               Food and Cantines
# 1001               Food and Cantines
# 1002               Food and Cantines
# 1003               Food and Cantines
# 1004               Food and Cantines
#
#                                                 Reports  Age   Gpa  Year  \
# 0     The limited access to research databases and m...   27  2.18     2
# 1     I'm having trouble finding the course material...   23  3.11     2
# 2     It's frustrating to have limited access to res...   20  3.68     2
# 3     I'm really struggling in one of my classes but...   20  1.30     2
# 4      I am really struggling with understanding the...   26  2.50     2
# ...

# %% [markdown]
# ##### Understanding Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Genre    1005 non-null   object
#  1   Reports  1005 non-null   object
#  2   Age      1005 non-null   int64
#  3   Gpa      1005 non-null   float64
#  4   Year     1005 non-null   int64
#  5   Count    1005 non-null   int64
#  6   Gender   1005 non-null   object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 55.1+ KB

# %%
df.describe()
# Out:
#                Age          Gpa         Year   Count
# count  1005.000000  1005.000000  1005.000000  1005.0
# mean     21.298507     2.088856     2.684577     1.0
# std       3.338841     1.208738     1.461665     0.0
# min      16.000000     0.010000     1.000000     1.0
# 25%      18.000000     1.080000     1.000000     1.0
# 50%      21.000000     2.110000     2.000000     1.0
# 75%      24.000000     3.090000     4.000000     1.0
# max      27.000000     4.970000     5.000000     1.0

# %% [markdown]
# ##### Check for Null Vlaues

# %%
df.isnull().sum()
# Out:
# Genre      0
# Reports    0
# Age        0
# Gpa        0
# Year       0
# Count      0
# Gender     0
# dtype: int64

# %% [markdown]
# ##### Visualizing Data

# %% [markdown]
# 2D Visualization of Departments where Each Student Report is Classified

# %%
import seaborn as sns

top = df['Genre'].value_counts()
plt.figure(figsize=(10,7))
sns.barplot(x=top.index,y=top.values)
plt.xticks(rotation=45)
plt.title('Frequent Student Complaint Genre',color = 'blue')
# Out:
# Text(0.5, 1.0, 'Frequent Student Complaint Genre')

# %% [markdown]
# Insight: We noticed that the top department that received the most complaint are the Academic Support and Resorces, Food and Cantines, Finacial suppport. The focus will be on these three departments.

# %% [markdown]
# 2D Visualisation of Top Departments that Recieve the Most Report

# %%
import seaborn as sns

top = df['Genre'].value_counts()
plt.figure(figsize=(10,7))
sns.barplot(x=top[:3].index,y=top.values[:3])
plt.xticks(rotation=45)
plt.title('Top Three Student Complaint Genre',color = 'blue')
# Out:
# Text(0.5, 1.0, 'Top Three Student Complaint Genre')

# %% [markdown]
# Checking for Correlation

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(corrmat, vmax=.8, square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# NOTE: No correlation exist for the Genre based on the age, Gpa and Academic year

# %% [markdown]
# ##### 2D Visualizaton of Age and Year to Genre Plot

# %%
sns.FacetGrid(df, hue="Genre", size=5) \
   .map(plt.scatter, "Age", "Year") \
   .add_legend()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# INSIGHT: This plot does not provide any information.

# %% [markdown]
# ##### 3D Visualizaton of Age, Gpa and Academic Year to Genre Plot

# %%
fig = px.scatter_3d(df, x='Age', y='Gpa',z='Year',
              color='Genre')
fig.show()

# %% [markdown]
# INSIGHT: Notice that most reports are from seniors and juniors and that is logical as these are the students who will be hopefully graduating within a year or 2 so they are seeking chances to enhance their experiences.
#
#
#  Likewise, If we filter out only Academic Workload we'll find out that most reports are from Freshmen and Sophomore students and that is logical as these are the students who are new to the university and are not yet accustommed to the academic workload.

# %%
fig = px.bar(df, x="Genre", y="Count", color="Year", title="Genre vs Count")
fig.show()

# %%
fig = px.bar(df, x="Genre", y="Count", color="Age", title="Genre vs Count")
fig.show()

# %% [markdown]
# ##### Understanding Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Genre    1005 non-null   object
#  1   Reports  1005 non-null   object
#  2   Age      1005 non-null   int64
#  3   Gpa      1005 non-null   float64
#  4   Year     1005 non-null   int64
#  5   Count    1005 non-null   int64
#  6   Gender   1005 non-null   object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 55.1+ KB

# %%
df.describe()
# Out:
#                Age          Gpa         Year   Count
# count  1005.000000  1005.000000  1005.000000  1005.0
# mean     21.298507     2.088856     2.684577     1.0
# std       3.338841     1.208738     1.461665     0.0
# min      16.000000     0.010000     1.000000     1.0
# 25%      18.000000     1.080000     1.000000     1.0
# 50%      21.000000     2.110000     2.000000     1.0
# 75%      24.000000     3.090000     4.000000     1.0
# max      27.000000     4.970000     5.000000     1.0

# %% [markdown]
# ##### Check for Null Vlaues

# %%
df.isnull().sum()
# Out:
# Genre      0
# Reports    0
# Age        0
# Gpa        0
# Year       0
# Count      0
# Gender     0
# dtype: int64

# %% [markdown]
# ##### Visualizing Data

# %% [markdown]
# 2D Visualization of Departments where Each Student Report is Classified

# %%
import seaborn as sns

top = df['Genre'].value_counts()
plt.figure(figsize=(10,7))
sns.barplot(x=top.index,y=top.values)
plt.xticks(rotation=45)
plt.title('Frequent Student Complaint Genre',color = 'blue')
# Out:
# Text(0.5, 1.0, 'Frequent Student Complaint Genre')

# %% [markdown]
# Insight: We noticed that the top department that received the most complaint are the Academic Support and Resorces, Food and Cantines, Finacial suppport. The focus will be on these three departments.

# %% [markdown]
# 2D Visualisation of Top Departments that Recieve the Most Report

# %%
import seaborn as sns

top = df['Genre'].value_counts()
plt.figure(figsize=(10,7))
sns.barplot(x=top[:3].index,y=top.values[:3])
plt.xticks(rotation=45)
plt.title('Top Three Student Complaint Genre',color = 'blue')
# Out:
# Text(0.5, 1.0, 'Top Three Student Complaint Genre')

# %% [markdown]
# Checking for Correlation

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(corrmat, vmax=.8, square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# NOTE: No correlation exist for the Genre based on the age, Gpa and Academic year

# %% [markdown]
# ##### 2D Visualizaton of Age and Year to Genre Plot

# %%
sns.FacetGrid(df, hue="Genre", size=5) \
   .map(plt.scatter, "Age", "Year") \
   .add_legend()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# INSIGHT: This plot does not provide any information.

# %% [markdown]
# ##### 3D Visualizaton of Age, Gpa and Academic Year to Genre Plot

# %%
fig = px.scatter_3d(df, x='Age', y='Gpa',z='Year',
              color='Genre')
fig.show()

# %% [markdown]
# INSIGHT: Notice that most reports are from seniors and juniors and that is logical as these are the students who will be hopefully graduating within a year or 2 so they are seeking chances to enhance their experiences.
#
#
#  Likewise, If we filter out only Academic Workload we'll find out that most reports are from Freshmen and Sophomore students and that is logical as these are the students who are new to the university and are not yet accustommed to the academic workload.

# %%
fig = px.bar(df, x="Genre", y="Count", color="Year", title="Genre vs Count")
fig.show()

# %%
fig = px.bar(df, x="Genre", y="Count", color="Age", title="Genre vs Count")
fig.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Import the dataset
df = pd.read_csv("university_student_complaint.csv")

# Determine the top departments receiving the most reports
top_departments = df['Genre'].value_counts().head(5)
print("Top Departments with Most Reports:")
print(top_departments)

# Cluster the reports
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(df['Reports'].values.astype('U'))

# Determine the optimal number of clusters using silhouette score
silhouette_scores = []
for n_clusters in range(2, 10):
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_scores.append(silhouette_score(X, cluster_labels))

optimal_num_clusters = silhouette_scores.index(max(silhouette_scores)) + 2
print("Optimal Number of Clusters:", optimal_num_clusters)

# Perform clustering with the optimal number of clusters
kmeans = KMeans(n_clusters=optimal_num_clusters, random_state=42)
cluster_labels = kmeans.fit_predict(X)

# Add the cluster labels to the DataFrame
df['Cluster'] = cluster_labels

# Identify the most reported teachers of the faculty
most_reported_teachers = df[df['Genre'] == 'Academic Support and Resources']['Reports'].value_counts().head(5)
print("Most Reported Teachers:")
print(most_reported_teachers)

# Check reporting patterns
reporting_patterns = df.groupby(['Genre', 'Cluster']).size().unstack(fill_value=0)
print("Reporting Patterns:")
print(reporting_patterns)

# Visualize the reporting patterns
reporting_patterns.plot(kind='bar', stacked=True)
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title("Reporting Patterns")
plt.legend(title="Cluster")
plt.show()
# Out:
# Top Departments with Most Reports:
# Academic Support and Resources    236
# Food and Cantines                 138
# Financial Support                  91
# Online learning                    90
# Career opportunities               89
# Name: Genre, dtype: int64
# Optimal Number of Clusters: 9
# Most Reported Teachers:
# The limited access to research databases and materials is causing a lot of frustration among students. We need better access to be able to succeed academically.    2
# The academic workload is causing significant stress and anxiety, and I am finding it hard to cope with the pressure.                                                2
# I've been feeling really exhausted lately, and it's been hard to stay motivated to study.                                                                           1
# I'm not very good at managing my time, and I often find myself struggling to balance my academic work with my other commitments.                                    1
# ...

# %%
# Importing libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("university_student_complaint.csv")

# Determine the top departments that receive the most reports
top_departments = df['Genre'].value_counts().head(5)
print("Top Departments with Most Reports:")
print(top_departments)

# Clustering the reports using K-means algorithm
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(df['Reports'])
k = 5  # Number of clusters
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(X)

# Add the predicted cluster labels to the dataset
df['Cluster'] = kmeans.labels_

# Identify the most reported teachers
most_reported_teachers = df.groupby('Cluster')['Reports'].apply(lambda x: x.value_counts().idxmax())
print("\nMost Reported Teachers:")
print(most_reported_teachers)

# Check reporting patterns
reporting_patterns = df.groupby(['Cluster', 'Genre']).size().unstack()
reporting_patterns.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Reporting Patterns')
plt.xlabel('Clusters')
plt.ylabel('Number of Reports')
plt.xticks(rotation=0)
plt.legend(title='Genre', bbox_to_anchor=(1, 1))
plt.show()
# Out:
# Top Departments with Most Reports:
# Academic Support and Resources    236
# Food and Cantines                 138
# Financial Support                  91
# Online learning                    90
# Career opportunities               89
# Name: Genre, dtype: int64
#
# Most Reported Teachers:
# Cluster
# 0    There seems to be a scarcity of available inte...
# 1    I'm trying to graduate early but there are onl...
# 2    The limited access to research databases and m...
# 3    The academic workload is causing significant s...
# 4     I'm not sure I'll be able to afford to finish...
# Name: Reports, dtype: object
